# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# File to Load (Remember to Change These)
file_to_load = "./Resources/cities.csv"

# %%
# Read Purchasing File and store into Pandas data frame
city_data = pd.read_csv(file_to_load)

# %%
city_data
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                      qaanaaq  77.4840  -69.3632     28.60        74
# 1                   lavrentiya  65.5833 -171.0000     21.07        88
# 2                       koumac -20.5667  164.2833     75.15        85
# 3                     buraydah  26.3260   43.9750     98.60        13
# 4                    mahebourg -20.4081   57.7000     78.80        78
# ..                         ...      ...       ...       ...       ...
# 546  santa isabel do rio negro  -0.4139  -65.0192     86.72        61
# 547                      amapa   1.0000  -52.0000     78.62        93
# 548                     lyndon  38.2567  -85.6016     53.60        76
# 549                   almaznyy  48.0448   40.0450     57.20        26
# 550                   sterling  39.0062  -77.4286     55.40        76
#
#      Cloudiness  Wind Speed Country             Date
# 0            61        4.45      GL  4/25/2021 14:15
# 1           100        3.91      RU  4/25/2021 14:12
# 2           100       11.52      NC  4/25/2021 14:15
# 3            75       10.36      SA  4/25/2021 14:15
# 4            75       13.80      MU  4/25/2021 14:15
# ..          ...         ...     ...              ...
# 546          81        5.66      BR  4/25/2021 14:17
# 547          98        3.18      BR  4/25/2021 14:13
# 548          90        6.91      US  4/25/2021 14:17
# 549           0        2.24      RU  4/25/2021 14:17
# 550          75       12.66      US  4/25/2021 14:17
#
# [551 rows x 9 columns]

# %%
city_data.to_html("city_data.html", index = False, classes = ["table", "table-striped", "table-hover"])
